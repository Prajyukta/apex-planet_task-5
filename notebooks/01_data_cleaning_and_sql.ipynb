# %% [markdown]
# # 01 Data Cleaning and SQL
# Load the raw batch, validate the data contract, and inspect cleaned outputs.

# %%
from pathlib import Path
import pandas as pd

raw = pd.read_csv(Path('..') / 'data/raw/retail_raw_stream.csv')
raw.info()
raw.head()

# %%
# SQL-ready analytical question (run in DuckDB or the warehouse):
# SELECT Region, SUM(Total_Revenue) AS revenue
# FROM master_cleaned_data
# GROUP BY Region
# ORDER BY revenue DESC;
